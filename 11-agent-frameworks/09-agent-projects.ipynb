# %% [markdown]
# # Agent Projects
#
# **Module:** 11-agent-frameworks
#
# **Notebook:** `09-agent-projects.ipynb`
#
# This expanded lesson goes beyond definitions: each topic includes *why it matters*, *how it works*, intuition, pitfalls, and when to use it—plus runnable Python demos, comparison aids, and exercises.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain and apply **Project 1 — LangGraph-style Support Graph** with clear contracts and failure modes
# - Explain and apply **Project 2 — CrewAI-style Research Crew** with clear contracts and failure modes
# - Explain and apply **Project 3 — AutoGen-style Coding Pair** with clear contracts and failure modes
# - Explain and apply **Project 4 — Typed Triage Agent (PydanticAI-style)** with clear contracts and failure modes
# - Explain and apply **Project 5 — HITL + Trace Wrapper** with clear contracts and failure modes
# - Explain and apply **Stretch Goals** with clear contracts and failure modes
# - Evaluate tradeoffs (quality, cost, latency, safety) for designs in this lesson
# - Implement small Python prototypes that make the ideas testable

# %% [markdown]
# ## How to Use This Notebook
#
# 1. Read the topic sections fully—do not jump only to code.
# 2. Run each demo; then change inputs to break them and fix them.
# 3. API examples use placeholders like `YOUR_API_KEY` or `os.environ.get(...)`.
# 4. Keep secrets out of git; treat prompts/tool schemas as versioned code.
# 5. Complete the **Try It Yourself** exercises before moving on.

# %% [markdown]
# ### Pipeline walkthrough — Agent Projects
#
# ```mermaid
# flowchart LR
#   A[Problem / user goal] --> B[Contract: IO + constraints]
#   B --> C[Implement core path]
#   C --> D[Validate / guardrails]
#   D --> E[Eval fixtures]
#   E --> F[Observe in production]
#   F -->|regressions| B
# ```
#
# ```text
# goal -> contract -> implement -> validate -> evaluate -> monitor -> revise
# ```

# %% [markdown]
# ## Curriculum Map
#
# This notebook's spine (preserve/cover all of these):
#
# 1. **Project 1 — LangGraph-style Support Graph**
# 2. **Project 2 — CrewAI-style Research Crew**
# 3. **Project 3 — AutoGen-style Coding Pair**
# 4. **Project 4 — Typed Triage Agent (PydanticAI-style)**
# 5. **Project 5 — HITL + Trace Wrapper**
# 6. **Stretch Goals**
#
# Read top-to-bottom once, then revisit weak spots with the exercises.

# %% [markdown]
# ## Project 1 — LangGraph-style Support Graph
#
# ### Definition
# **Project 1 — LangGraph-style Support Graph** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 1 — LangGraph-style Support Graph as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 1 — LangGraph-style Support Graph
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agent frameworks: choosing framework theater over a clear control loop
#
# ### When to use
# Use Project 1 — LangGraph-style Support Graph when your product path depends on this concern in agent frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.
#
# ### Quick reference
#
# | Lens | Question |
# |------|----------|
# | Product | What user outcome does Project 1 — LangGraph-style Support Graph improve? |
# | Engineering | What is the interface / data contract? |
# | Safety | What can go wrong if it fails open? |
# | Ops | How will we notice regressions? |

# %%
# Demo: make "Project 1 — LangGraph-style Support Graph" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 1 — LangGraph-style Support Graph"
    notebook: str = "09-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_0 = ConceptContract()
print(json.dumps({"contract": asdict(contract_0), "health": contract_0.health()}, indent=2))

# %%
class Pipeline:
    def __init__(self):
        self.stages = []
    def add(self, name, fn):
        self.stages.append((name, fn)); return self
    def run(self, data):
        audit = []
        for name, fn in self.stages:
            data = fn(data)
            audit.append({"stage": name, "type": type(data).__name__})
        return data, audit

result, audit = (
    Pipeline()
    .add("normalize", lambda s: s.strip().lower())
    .add("tokens", lambda s: s.split())
    .add("features", lambda toks: {"n": len(toks), "head": toks[:3]})
    .run("  SSO Login Loop  ")
)
print(result); print(audit)

# %%
# Parallel fan-out / fan-in sketch
from concurrent.futures import ThreadPoolExecutor

def analyze(kind, text):
    return {"kind": kind, "len": len(text)}

text = "investigate checkout latency"
with ThreadPoolExecutor(max_workers=3) as ex:
    parts = list(ex.map(lambda k: analyze(k, text), ["security", "perf", "ux"]))
merged = {p["kind"]: p["len"] for p in parts}
print(merged)

# %% [markdown]
# ## Project 2 — CrewAI-style Research Crew
#
# ### Definition
# **Project 2 — CrewAI-style Research Crew** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 2 — CrewAI-style Research Crew as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 2 — CrewAI-style Research Crew
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agent frameworks: choosing framework theater over a clear control loop
#
# ### When to use
# Use Project 2 — CrewAI-style Research Crew when your product path depends on this concern in agent frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 2 — CrewAI-style Research Crew" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 2 — CrewAI-style Research Crew"
    notebook: str = "09-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_1 = ConceptContract()
print(json.dumps({"contract": asdict(contract_1), "health": contract_1.health()}, indent=2))

# %%
from enum import Enum

class Phase(Enum):
    PLAN = "plan"
    ACT = "act"
    CHECK = "check"
    DONE = "done"

def agent_loop(goal: str, max_steps=3):
    log = []
    phase = Phase.PLAN
    for step in range(max_steps):
        if phase == Phase.PLAN:
            plan = [f"step{i+1}" for i in range(2)]
            log.append(("plan", plan)); phase = Phase.ACT
        elif phase == Phase.ACT:
            log.append(("act", f"execute {goal}")); phase = Phase.CHECK
        elif phase == Phase.CHECK:
            log.append(("check", "ok")); phase = Phase.DONE
        else:
            break
    return log

print(agent_loop("triage ticket"))

# %%
# Supervisor routes to specialists
def route_intent(text: str) -> str:
    t = text.lower()
    if "refund" in t or "invoice" in t: return "billing_agent"
    if "login" in t or "sso" in t: return "auth_agent"
    return "general_agent"

for q in ["refund please", "SSO loop", "hello"]:
    print(q, "->", route_intent(q))

# %% [markdown]
# ### Worked scenario — Project 2 — CrewAI-style Research Crew
#
# **Situation:** A team wants to productionize a feature involving **Project 2 — CrewAI-style Research Crew**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Project 3 — AutoGen-style Coding Pair
#
# ### Definition
# **Project 3 — AutoGen-style Coding Pair** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 3 — AutoGen-style Coding Pair as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 3 — AutoGen-style Coding Pair
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agent frameworks: choosing framework theater over a clear control loop
#
# ### When to use
# Use Project 3 — AutoGen-style Coding Pair when your product path depends on this concern in agent frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 3 — AutoGen-style Coding Pair" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 3 — AutoGen-style Coding Pair"
    notebook: str = "09-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_2 = ConceptContract()
print(json.dumps({"contract": asdict(contract_2), "health": contract_2.health()}, indent=2))

# %%
# Framework mental model: compose runnable steps
class Runnable:
    def __init__(self, fn): self.fn = fn
    def __or__(self, other):
        return Runnable(lambda x: other.fn(self.fn(x)))
    def invoke(self, x): return self.fn(x)

prompt = Runnable(lambda q: f"Answer briefly: {q}")
model = Runnable(lambda p: f"<model-output for: {p[:40]}...>")
parse = Runnable(lambda t: {"text": t, "n": len(t)})
chain = prompt | model | parse
print(chain.invoke("What is LCEL?"))

# %%
# Index → retrieve → generate sketch (RAG-shaped)
NODES = [{"id": 1, "text": "LCEL composes runnables with |"}, {"id": 2, "text": "LlamaIndex focuses on data indexes"}]

def retrieve(q, k=1):
    return sorted(NODES, key=lambda n: len(set(q.lower().split()) & set(n["text"].lower().split())), reverse=True)[:k]

def generate(q, nodes):
    ctx = " | ".join(n["text"] for n in nodes)
    return f"Q: {q}\nCTX: {ctx}\nA: Based on context, {nodes[0]['text']}."

print(generate("What is LCEL?", retrieve("LCEL compose")))

# %% [markdown]
# ## Project 4 — Typed Triage Agent (PydanticAI-style)
#
# ### Definition
# **Project 4 — Typed Triage Agent (PydanticAI-style)** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 4 — Typed Triage Agent (PydanticAI-style) as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 4 — Typed Triage Agent (PydanticAI-style)
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agent frameworks: choosing framework theater over a clear control loop
#
# ### When to use
# Use Project 4 — Typed Triage Agent (PydanticAI-style) when your product path depends on this concern in agent frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 4 — Typed Triage Agent (PydanticAI-style)" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 4 — Typed Triage Agent (PydanticAI-style)"
    notebook: str = "09-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_3 = ConceptContract()
print(json.dumps({"contract": asdict(contract_3), "health": contract_3.health()}, indent=2))

# %%
import json, re

def extract_json(text: str):
    text = text.strip()
    m = re.search(r"```(?:json)?\s*([\s\S]*?)```", text)
    if m:
        text = m.group(1).strip()
    text = text.replace(",}", "}").replace(",]", "]")
    return json.loads(text)

schema_required = {"category", "priority"}
samples = [
    '{"category":"auth","priority":"P1"}',
    '```json\n{"category":"billing","priority":"P2",}\n```',
]
for s in samples:
    obj = extract_json(s)
    assert schema_required <= set(obj)
    print("ok:", obj)

# %%
# Realistic API response_format shape (placeholder key)
import os
request = {
    "model": "gpt-4.1-mini",
    "messages": [
        {"role": "system", "content": "Return JSON only."},
        {"role": "user", "content": "Classify: SSO login loop"},
    ],
    "response_format": {"type": "json_object"},
}
headers = {"Authorization": f"Bearer {os.environ.get('OPENAI_API_KEY', 'YOUR_API_KEY')}"}
response = {
    "choices": [{"message": {"content": '{"category":"auth","priority":"P1"}'}}],
    "usage": {"prompt_tokens": 90, "completion_tokens": 12},
}
print(headers["Authorization"][:22] + "...", json.loads(response["choices"][0]["message"]["content"]))

# %% [markdown]
# ### Worked scenario — Project 4 — Typed Triage Agent (PydanticAI-style)
#
# **Situation:** A team wants to productionize a feature involving **Project 4 — Typed Triage Agent (PydanticAI-style)**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Project 5 — HITL + Trace Wrapper
#
# ### Definition
# **Project 5 — HITL + Trace Wrapper** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 5 — HITL + Trace Wrapper as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 5 — HITL + Trace Wrapper
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agent frameworks: choosing framework theater over a clear control loop
#
# ### When to use
# Use Project 5 — HITL + Trace Wrapper when your product path depends on this concern in agent frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 5 — HITL + Trace Wrapper" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 5 — HITL + Trace Wrapper"
    notebook: str = "09-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_4 = ConceptContract()
print(json.dumps({"contract": asdict(contract_4), "health": contract_4.health()}, indent=2))

# %%
# Demo: before/after quality rubric for "Project 5 — HITL + Trace Wrapper"
def score_artifact(artifact: dict, rubric: list[str]) -> dict:
    missing = [r for r in rubric if not artifact.get(r)]
    return {"score": round(1 - len(missing)/max(1,len(rubric)), 2), "missing": missing}

rubric = ["definition", "example", "failure_mode", "metric"]
weak = {"definition": "Project 5 — HITL + Trace Wrapper"}
strong = {"definition": "Project 5 — HITL + Trace Wrapper", "example": "worked example", "failure_mode": "empty input", "metric": "exact_match"}
print("weak", score_artifact(weak, rubric))
print("strong", score_artifact(strong, rubric))

# %%
# Demo: operational checklist runner for "Project 5 — HITL + Trace Wrapper"
checks = {
    "has_owner": True,
    "has_eval_set": True,
    "has_token_budget": False,
    "has_alert": False,
}
failed = [k for k, ok in checks.items() if not ok]
print({"topic": "Project 5 — HITL + Trace Wrapper", "passed": len(checks)-len(failed), "failed": failed})

# %% [markdown]
# ## Stretch Goals
#
# ### Definition
# **Stretch Goals** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Stretch Goals as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Stretch Goals
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agent frameworks: choosing framework theater over a clear control loop
#
# ### When to use
# Use Stretch Goals when your product path depends on this concern in agent frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Stretch Goals" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Stretch Goals"
    notebook: str = "09-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_5 = ConceptContract()
print(json.dumps({"contract": asdict(contract_5), "health": contract_5.health()}, indent=2))

# %%
# Demo: before/after quality rubric for "Stretch Goals"
def score_artifact(artifact: dict, rubric: list[str]) -> dict:
    missing = [r for r in rubric if not artifact.get(r)]
    return {"score": round(1 - len(missing)/max(1,len(rubric)), 2), "missing": missing}

rubric = ["definition", "example", "failure_mode", "metric"]
weak = {"definition": "Stretch Goals"}
strong = {"definition": "Stretch Goals", "example": "worked example", "failure_mode": "empty input", "metric": "exact_match"}
print("weak", score_artifact(weak, rubric))
print("strong", score_artifact(strong, rubric))

# %%
# Demo: operational checklist runner for "Stretch Goals"
checks = {
    "has_owner": True,
    "has_eval_set": True,
    "has_token_budget": False,
    "has_alert": False,
}
failed = [k for k, ok in checks.items() if not ok]
print({"topic": "Stretch Goals", "passed": len(checks)-len(failed), "failed": failed})

# %% [markdown]
# ### Worked scenario — Stretch Goals
#
# **Situation:** A team wants to productionize a feature involving **Stretch Goals**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Comparison Snapshot
#
# Use this table when reviewing designs in **Agent Projects**.
#
# | Topic | Do | Don't |
# |-------|----|-------|
# | Project 1 — LangGraph-style Support Graph | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 2 — CrewAI-style Research Crew | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 3 — AutoGen-style Coding Pair | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 4 — Typed Triage Agent (PydanticAI-style) | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 5 — HITL + Trace Wrapper | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Stretch Goals | Design carefully; measure; bound cost | Skipping eval / unbounded loops |

# %% [markdown]
# ## Glossary / Key Terms
#
# | Term | Meaning |
# |------|---------|
# | Project 1 — LangGraph-style Support Graph | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 2 — CrewAI-style Research Crew | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 3 — AutoGen-style Coding Pair | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 4 — Typed Triage Agent (PydanticAI-style) | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 5 — HITL + Trace Wrapper | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Stretch Goals | Key concept covered in this notebook; see its section for definition and pitfalls |

# %% [markdown]
# ## Summary & Key Takeaways
#
# - **Agent Projects** is a production concern: contracts, evals, and guardrails beat vibe-driven prompting.
# - Every major topic above includes definition, motivation, mechanism, intuition, pitfalls, and usage guidance—use that checklist in design reviews.
# - Prefer small, measurable demos before framework sprawl.
# - Bound loops, validate tool args, and keep API keys in environment variables (`YOUR_API_KEY` is a placeholder only).
# - Carry forward: connect these ideas to the next notebooks in **11-agent-frameworks**.

# %% [markdown]
# ## Try It Yourself
#
# 1. Implement a failing test/fixture for **Project 1 — LangGraph-style Support Graph**, then fix your demo until it passes.
# 2. Implement a failing test/fixture for **Project 2 — CrewAI-style Research Crew**, then fix your demo until it passes.
# 3. Implement a failing test/fixture for **Project 3 — AutoGen-style Coding Pair**, then fix your demo until it passes.
# 4. Implement a failing test/fixture for **Project 4 — Typed Triage Agent (PydanticAI-style)**, then fix your demo until it passes.
# 5. Implement a failing test/fixture for **Project 5 — HITL + Trace Wrapper**, then fix your demo until it passes.
# 6. Estimate token cost for your prompt/tool trace at 1k and 100k requests/day.
# 7. Write a 5-row comparison of two design alternatives from this notebook; pick one with explicit criteria.
# 8. Red-team your solution with empty input, hostile input, and a tool/API timeout.
