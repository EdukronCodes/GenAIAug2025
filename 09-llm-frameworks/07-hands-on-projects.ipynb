# %% [markdown]
# # Hands-on Projects
#
# **Module:** 09-llm-frameworks
#
# **Notebook:** `07-hands-on-projects.ipynb`
#
# This expanded lesson goes beyond definitions: each topic includes *why it matters*, *how it works*, intuition, pitfalls, and when to use it—plus runnable Python demos, comparison aids, and exercises.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain and apply **Project 1 — Mini LCEL Pipeline** with clear contracts and failure modes
# - Explain and apply **Project 2 — LlamaIndex-style RAG** with clear contracts and failure modes
# - Explain and apply **Project 3 — Haystack-style Explicit Pipeline** with clear contracts and failure modes
# - Explain and apply **Project 4 — DSPy-style Signature Program** with clear contracts and failure modes
# - Explain and apply **Project 5 — Framework Bakeoff** with clear contracts and failure modes
# - Explain and apply **Self-Check** with clear contracts and failure modes
# - Evaluate tradeoffs (quality, cost, latency, safety) for designs in this lesson
# - Implement small Python prototypes that make the ideas testable

# %% [markdown]
# ## How to Use This Notebook
#
# 1. Read the topic sections fully—do not jump only to code.
# 2. Run each demo; then change inputs to break them and fix them.
# 3. API examples use placeholders like `YOUR_API_KEY` or `os.environ.get(...)`.
# 4. Keep secrets out of git; treat prompts/tool schemas as versioned code.
# 5. Complete the **Try It Yourself** exercises before moving on.

# %% [markdown]
# ### Pipeline walkthrough — Hands-on Projects
#
# ```mermaid
# flowchart LR
#   A[Problem / user goal] --> B[Contract: IO + constraints]
#   B --> C[Implement core path]
#   C --> D[Validate / guardrails]
#   D --> E[Eval fixtures]
#   E --> F[Observe in production]
#   F -->|regressions| B
# ```
#
# ```text
# goal -> contract -> implement -> validate -> evaluate -> monitor -> revise
# ```

# %% [markdown]
# ## Curriculum Map
#
# This notebook's spine (preserve/cover all of these):
#
# 1. **Project 1 — Mini LCEL Pipeline**
# 2. **Project 2 — LlamaIndex-style RAG**
# 3. **Project 3 — Haystack-style Explicit Pipeline**
# 4. **Project 4 — DSPy-style Signature Program**
# 5. **Project 5 — Framework Bakeoff**
# 6. **Self-Check**
#
# Read top-to-bottom once, then revisit weak spots with the exercises.

# %% [markdown]
# ## Project 1 — Mini LCEL Pipeline
#
# ### Definition
# **Project 1 — Mini LCEL Pipeline** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 1 — Mini LCEL Pipeline as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 1 — Mini LCEL Pipeline
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of LLM frameworks: framework lock-in, opaque magic, and untested compositions
#
# ### When to use
# Use Project 1 — Mini LCEL Pipeline when your product path depends on this concern in LLM frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.
#
# ### Quick reference
#
# | Lens | Question |
# |------|----------|
# | Product | What user outcome does Project 1 — Mini LCEL Pipeline improve? |
# | Engineering | What is the interface / data contract? |
# | Safety | What can go wrong if it fails open? |
# | Ops | How will we notice regressions? |

# %%
# Demo: make "Project 1 — Mini LCEL Pipeline" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 1 — Mini LCEL Pipeline"
    notebook: str = "07-hands-on-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_0 = ConceptContract()
print(json.dumps({"contract": asdict(contract_0), "health": contract_0.health()}, indent=2))

# %%
class Pipeline:
    def __init__(self):
        self.stages = []
    def add(self, name, fn):
        self.stages.append((name, fn)); return self
    def run(self, data):
        audit = []
        for name, fn in self.stages:
            data = fn(data)
            audit.append({"stage": name, "type": type(data).__name__})
        return data, audit

result, audit = (
    Pipeline()
    .add("normalize", lambda s: s.strip().lower())
    .add("tokens", lambda s: s.split())
    .add("features", lambda toks: {"n": len(toks), "head": toks[:3]})
    .run("  SSO Login Loop  ")
)
print(result); print(audit)

# %%
# Parallel fan-out / fan-in sketch
from concurrent.futures import ThreadPoolExecutor

def analyze(kind, text):
    return {"kind": kind, "len": len(text)}

text = "investigate checkout latency"
with ThreadPoolExecutor(max_workers=3) as ex:
    parts = list(ex.map(lambda k: analyze(k, text), ["security", "perf", "ux"]))
merged = {p["kind"]: p["len"] for p in parts}
print(merged)

# %% [markdown]
# ## Project 2 — LlamaIndex-style RAG
#
# ### Definition
# **Project 2 — LlamaIndex-style RAG** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 2 — LlamaIndex-style RAG as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 2 — LlamaIndex-style RAG
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of LLM frameworks: framework lock-in, opaque magic, and untested compositions
#
# ### When to use
# Use Project 2 — LlamaIndex-style RAG when your product path depends on this concern in LLM frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 2 — LlamaIndex-style RAG" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 2 — LlamaIndex-style RAG"
    notebook: str = "07-hands-on-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_1 = ConceptContract()
print(json.dumps({"contract": asdict(contract_1), "health": contract_1.health()}, indent=2))

# %%
# Framework mental model: compose runnable steps
class Runnable:
    def __init__(self, fn): self.fn = fn
    def __or__(self, other):
        return Runnable(lambda x: other.fn(self.fn(x)))
    def invoke(self, x): return self.fn(x)

prompt = Runnable(lambda q: f"Answer briefly: {q}")
model = Runnable(lambda p: f"<model-output for: {p[:40]}...>")
parse = Runnable(lambda t: {"text": t, "n": len(t)})
chain = prompt | model | parse
print(chain.invoke("What is LCEL?"))

# %%
# Index → retrieve → generate sketch (RAG-shaped)
NODES = [{"id": 1, "text": "LCEL composes runnables with |"}, {"id": 2, "text": "LlamaIndex focuses on data indexes"}]

def retrieve(q, k=1):
    return sorted(NODES, key=lambda n: len(set(q.lower().split()) & set(n["text"].lower().split())), reverse=True)[:k]

def generate(q, nodes):
    ctx = " | ".join(n["text"] for n in nodes)
    return f"Q: {q}\nCTX: {ctx}\nA: Based on context, {nodes[0]['text']}."

print(generate("What is LCEL?", retrieve("LCEL compose")))

# %% [markdown]
# ### Worked scenario — Project 2 — LlamaIndex-style RAG
#
# **Situation:** A team wants to productionize a feature involving **Project 2 — LlamaIndex-style RAG**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Project 3 — Haystack-style Explicit Pipeline
#
# ### Definition
# **Project 3 — Haystack-style Explicit Pipeline** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 3 — Haystack-style Explicit Pipeline as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 3 — Haystack-style Explicit Pipeline
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of LLM frameworks: framework lock-in, opaque magic, and untested compositions
#
# ### When to use
# Use Project 3 — Haystack-style Explicit Pipeline when your product path depends on this concern in LLM frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 3 — Haystack-style Explicit Pipeline" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 3 — Haystack-style Explicit Pipeline"
    notebook: str = "07-hands-on-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_2 = ConceptContract()
print(json.dumps({"contract": asdict(contract_2), "health": contract_2.health()}, indent=2))

# %%
class Pipeline:
    def __init__(self):
        self.stages = []
    def add(self, name, fn):
        self.stages.append((name, fn)); return self
    def run(self, data):
        audit = []
        for name, fn in self.stages:
            data = fn(data)
            audit.append({"stage": name, "type": type(data).__name__})
        return data, audit

result, audit = (
    Pipeline()
    .add("normalize", lambda s: s.strip().lower())
    .add("tokens", lambda s: s.split())
    .add("features", lambda toks: {"n": len(toks), "head": toks[:3]})
    .run("  SSO Login Loop  ")
)
print(result); print(audit)

# %%
# Parallel fan-out / fan-in sketch
from concurrent.futures import ThreadPoolExecutor

def analyze(kind, text):
    return {"kind": kind, "len": len(text)}

text = "investigate checkout latency"
with ThreadPoolExecutor(max_workers=3) as ex:
    parts = list(ex.map(lambda k: analyze(k, text), ["security", "perf", "ux"]))
merged = {p["kind"]: p["len"] for p in parts}
print(merged)

# %% [markdown]
# ## Project 4 — DSPy-style Signature Program
#
# ### Definition
# **Project 4 — DSPy-style Signature Program** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 4 — DSPy-style Signature Program as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 4 — DSPy-style Signature Program
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of LLM frameworks: framework lock-in, opaque magic, and untested compositions
#
# ### When to use
# Use Project 4 — DSPy-style Signature Program when your product path depends on this concern in LLM frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 4 — DSPy-style Signature Program" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 4 — DSPy-style Signature Program"
    notebook: str = "07-hands-on-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_3 = ConceptContract()
print(json.dumps({"contract": asdict(contract_3), "health": contract_3.health()}, indent=2))

# %%
# Framework mental model: compose runnable steps
class Runnable:
    def __init__(self, fn): self.fn = fn
    def __or__(self, other):
        return Runnable(lambda x: other.fn(self.fn(x)))
    def invoke(self, x): return self.fn(x)

prompt = Runnable(lambda q: f"Answer briefly: {q}")
model = Runnable(lambda p: f"<model-output for: {p[:40]}...>")
parse = Runnable(lambda t: {"text": t, "n": len(t)})
chain = prompt | model | parse
print(chain.invoke("What is LCEL?"))

# %%
# Index → retrieve → generate sketch (RAG-shaped)
NODES = [{"id": 1, "text": "LCEL composes runnables with |"}, {"id": 2, "text": "LlamaIndex focuses on data indexes"}]

def retrieve(q, k=1):
    return sorted(NODES, key=lambda n: len(set(q.lower().split()) & set(n["text"].lower().split())), reverse=True)[:k]

def generate(q, nodes):
    ctx = " | ".join(n["text"] for n in nodes)
    return f"Q: {q}\nCTX: {ctx}\nA: Based on context, {nodes[0]['text']}."

print(generate("What is LCEL?", retrieve("LCEL compose")))

# %% [markdown]
# ### Worked scenario — Project 4 — DSPy-style Signature Program
#
# **Situation:** A team wants to productionize a feature involving **Project 4 — DSPy-style Signature Program**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Project 5 — Framework Bakeoff
#
# ### Definition
# **Project 5 — Framework Bakeoff** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 5 — Framework Bakeoff as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 5 — Framework Bakeoff
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of LLM frameworks: framework lock-in, opaque magic, and untested compositions
#
# ### When to use
# Use Project 5 — Framework Bakeoff when your product path depends on this concern in LLM frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 5 — Framework Bakeoff" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 5 — Framework Bakeoff"
    notebook: str = "07-hands-on-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_4 = ConceptContract()
print(json.dumps({"contract": asdict(contract_4), "health": contract_4.health()}, indent=2))

# %%
# Framework mental model: compose runnable steps
class Runnable:
    def __init__(self, fn): self.fn = fn
    def __or__(self, other):
        return Runnable(lambda x: other.fn(self.fn(x)))
    def invoke(self, x): return self.fn(x)

prompt = Runnable(lambda q: f"Answer briefly: {q}")
model = Runnable(lambda p: f"<model-output for: {p[:40]}...>")
parse = Runnable(lambda t: {"text": t, "n": len(t)})
chain = prompt | model | parse
print(chain.invoke("What is LCEL?"))

# %%
# Index → retrieve → generate sketch (RAG-shaped)
NODES = [{"id": 1, "text": "LCEL composes runnables with |"}, {"id": 2, "text": "LlamaIndex focuses on data indexes"}]

def retrieve(q, k=1):
    return sorted(NODES, key=lambda n: len(set(q.lower().split()) & set(n["text"].lower().split())), reverse=True)[:k]

def generate(q, nodes):
    ctx = " | ".join(n["text"] for n in nodes)
    return f"Q: {q}\nCTX: {ctx}\nA: Based on context, {nodes[0]['text']}."

print(generate("What is LCEL?", retrieve("LCEL compose")))

# %% [markdown]
# ## Self-Check
#
# ### Definition
# **Self-Check** is a core building block in 07-hands-on-projects within LLM frameworks. Treat it as an orchestration layer—useful only when it clarifies ownership of steps: something you can name, version, test, and operate.
#
# ### Why it matters
# In LLM frameworks, weak designs around Self-Check typically surface as framework lock-in, opaque magic, and untested compositions. Investing here improves reliability, debuggability, and the ability to change models later.
#
# ### How it works
# For Self-Check: (1) write an explicit input/output contract, (2) implement the minimal happy path, (3) validate and add guardrails, (4) cover golden + adversarial fixtures, (5) wire observability. Your durable artifacts should look like runnable chains, indexes, and portable pipelines.
#
# ### Intuition
# Explain Self-Check as an orchestration layer—useful only when it clarifies ownership of steps. If a new engineer cannot tell what is trusted input, what is allowed action, and what 'done' means, the design is still fuzzy.
#
# ### Pitfalls
# - Treating Self-Check as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Self-Check
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of LLM frameworks: framework lock-in, opaque magic, and untested compositions
#
# ### When to use
# Use Self-Check when your product path depends on this concern in LLM frameworks. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Self-Check" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Self-Check"
    notebook: str = "07-hands-on-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_5 = ConceptContract()
print(json.dumps({"contract": asdict(contract_5), "health": contract_5.health()}, indent=2))

# %%
# Demo: before/after quality rubric for "Self-Check"
def score_artifact(artifact: dict, rubric: list[str]) -> dict:
    missing = [r for r in rubric if not artifact.get(r)]
    return {"score": round(1 - len(missing)/max(1,len(rubric)), 2), "missing": missing}

rubric = ["definition", "example", "failure_mode", "metric"]
weak = {"definition": "Self-Check"}
strong = {"definition": "Self-Check", "example": "worked example", "failure_mode": "empty input", "metric": "exact_match"}
print("weak", score_artifact(weak, rubric))
print("strong", score_artifact(strong, rubric))

# %%
# Demo: operational checklist runner for "Self-Check"
checks = {
    "has_owner": True,
    "has_eval_set": True,
    "has_token_budget": False,
    "has_alert": False,
}
failed = [k for k, ok in checks.items() if not ok]
print({"topic": "Self-Check", "passed": len(checks)-len(failed), "failed": failed})

# %% [markdown]
# ### Worked scenario — Self-Check
#
# **Situation:** A team wants to productionize a feature involving **Self-Check**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Comparison Snapshot
#
# Use this table when reviewing designs in **Hands-on Projects**.
#
# | Topic | Do | Don't |
# |-------|----|-------|
# | Project 1 — Mini LCEL Pipeline | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 2 — LlamaIndex-style RAG | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 3 — Haystack-style Explicit Pipeline | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 4 — DSPy-style Signature Program | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 5 — Framework Bakeoff | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Self-Check | Design carefully; measure; bound cost | Skipping eval / unbounded loops |

# %% [markdown]
# ## Glossary / Key Terms
#
# | Term | Meaning |
# |------|---------|
# | Project 1 — Mini LCEL Pipeline | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 2 — LlamaIndex-style RAG | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 3 — Haystack-style Explicit Pipeline | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 4 — DSPy-style Signature Program | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 5 — Framework Bakeoff | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Self-Check | Key concept covered in this notebook; see its section for definition and pitfalls |

# %% [markdown]
# ## Summary & Key Takeaways
#
# - **Hands-on Projects** is a production concern: contracts, evals, and guardrails beat vibe-driven prompting.
# - Every major topic above includes definition, motivation, mechanism, intuition, pitfalls, and usage guidance—use that checklist in design reviews.
# - Prefer small, measurable demos before framework sprawl.
# - Bound loops, validate tool args, and keep API keys in environment variables (`YOUR_API_KEY` is a placeholder only).
# - Carry forward: connect these ideas to the next notebooks in **09-llm-frameworks**.

# %% [markdown]
# ## Try It Yourself
#
# 1. Implement a failing test/fixture for **Project 1 — Mini LCEL Pipeline**, then fix your demo until it passes.
# 2. Implement a failing test/fixture for **Project 2 — LlamaIndex-style RAG**, then fix your demo until it passes.
# 3. Implement a failing test/fixture for **Project 3 — Haystack-style Explicit Pipeline**, then fix your demo until it passes.
# 4. Implement a failing test/fixture for **Project 4 — DSPy-style Signature Program**, then fix your demo until it passes.
# 5. Implement a failing test/fixture for **Project 5 — Framework Bakeoff**, then fix your demo until it passes.
# 6. Estimate token cost for your prompt/tool trace at 1k and 100k requests/day.
# 7. Write a 5-row comparison of two design alternatives from this notebook; pick one with explicit criteria.
# 8. Red-team your solution with empty input, hostile input, and a tool/API timeout.
