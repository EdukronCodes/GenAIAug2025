# %% [markdown]
# # Agent Projects
#
# **Module:** 10-agentic-ai-concepts
#
# **Notebook:** `10-agent-projects.ipynb`
#
# This expanded lesson goes beyond definitions: each topic includes *why it matters*, *how it works*, intuition, pitfalls, and when to use it—plus runnable Python demos, comparison aids, and exercises.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain and apply **Project 1 — Research ReAct Agent** with clear contracts and failure modes
# - Explain and apply **Project 2 — Support Agent with Memory** with clear contracts and failure modes
# - Explain and apply **Project 3 — Plan-Execute Trip Planner** with clear contracts and failure modes
# - Explain and apply **Project 4 — Multi-Agent Review Duo** with clear contracts and failure modes
# - Explain and apply **Project 5 — HITL Refund Gate** with clear contracts and failure modes
# - Explain and apply **Lightweight Evaluation** with clear contracts and failure modes
# - Evaluate tradeoffs (quality, cost, latency, safety) for designs in this lesson
# - Implement small Python prototypes that make the ideas testable

# %% [markdown]
# ## How to Use This Notebook
#
# 1. Read the topic sections fully—do not jump only to code.
# 2. Run each demo; then change inputs to break them and fix them.
# 3. API examples use placeholders like `YOUR_API_KEY` or `os.environ.get(...)`.
# 4. Keep secrets out of git; treat prompts/tool schemas as versioned code.
# 5. Complete the **Try It Yourself** exercises before moving on.

# %% [markdown]
# ### Pipeline walkthrough — Agent Projects
#
# ```mermaid
# flowchart LR
#   A[Problem / user goal] --> B[Contract: IO + constraints]
#   B --> C[Implement core path]
#   C --> D[Validate / guardrails]
#   D --> E[Eval fixtures]
#   E --> F[Observe in production]
#   F -->|regressions| B
# ```
#
# ```text
# goal -> contract -> implement -> validate -> evaluate -> monitor -> revise
# ```

# %% [markdown]
# ## Curriculum Map
#
# This notebook's spine (preserve/cover all of these):
#
# 1. **Project 1 — Research ReAct Agent**
# 2. **Project 2 — Support Agent with Memory**
# 3. **Project 3 — Plan-Execute Trip Planner**
# 4. **Project 4 — Multi-Agent Review Duo**
# 5. **Project 5 — HITL Refund Gate**
# 6. **Lightweight Evaluation**
#
# Read top-to-bottom once, then revisit weak spots with the exercises.

# %% [markdown]
# ## Project 1 — Research ReAct Agent
#
# ### Definition
# **Project 1 — Research ReAct Agent** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 1 — Research ReAct Agent as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 1 — Research ReAct Agent
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agentic systems: runaway tool loops, unverifiable plans, and missing human gates
#
# ### When to use
# Use Project 1 — Research ReAct Agent when your product path depends on this concern in agentic systems. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.
#
# ### Quick reference
#
# | Lens | Question |
# |------|----------|
# | Product | What user outcome does Project 1 — Research ReAct Agent improve? |
# | Engineering | What is the interface / data contract? |
# | Safety | What can go wrong if it fails open? |
# | Ops | How will we notice regressions? |

# %%
# Demo: make "Project 1 — Research ReAct Agent" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 1 — Research ReAct Agent"
    notebook: str = "10-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_0 = ConceptContract()
print(json.dumps({"contract": asdict(contract_0), "health": contract_0.health()}, indent=2))

# %%
import json

import ast, operator
_OPS = {ast.Add: operator.add, ast.Sub: operator.sub, ast.Mult: operator.mul, ast.Div: operator.truediv}

def _safe_calc(expr: str):
    node = ast.parse(expr, mode="eval")
    def ev(n):
        if isinstance(n, ast.Expression): return ev(n.body)
        if isinstance(n, ast.Constant) and isinstance(n.value, (int, float)): return n.value
        if isinstance(n, ast.BinOp) and type(n.op) in _OPS: return _OPS[type(n.op)](ev(n.left), ev(n.right))
        raise ValueError("unsupported")
    return ev(node)

TOOLS = {
    "search_docs": lambda q: [{"id": "d1", "text": f"Snippet for {q}"}],
    "safe_calc": lambda expr: {"result": _safe_calc(expr)},
}

def route(name: str, args_json: str) -> dict:
    if name not in TOOLS:
        return {"ok": False, "error": "unknown_tool"}
    try:
        args = json.loads(args_json)
        return {"ok": True, "observation": TOOLS[name](**args)}
    except Exception as e:
        return {"ok": False, "error": type(e).__name__}

print(route("search_docs", '{"q":"SSO"}'))
print(route("safe_calc", '{"expr":"21*2"}'))

# %%
# ReAct-style trace (pedagogical)
trace = [
    ("Thought", "Need docs on SSO redirects"),
    ("Action", "search_docs"),
    ("Args", {"q": "SSO redirect allowlist"}),
    ("Observation", route("search_docs", '{"q":"SSO redirect allowlist"}')),
    ("Final", "Redirect URLs must match the allowlist."),
]
for k, v in trace:
    print(f"{k}: {v}")

# %% [markdown]
# ## Project 2 — Support Agent with Memory
#
# ### Definition
# **Project 2 — Support Agent with Memory** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 2 — Support Agent with Memory as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 2 — Support Agent with Memory
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agentic systems: runaway tool loops, unverifiable plans, and missing human gates
#
# ### When to use
# Use Project 2 — Support Agent with Memory when your product path depends on this concern in agentic systems. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 2 — Support Agent with Memory" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 2 — Support Agent with Memory"
    notebook: str = "10-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_1 = ConceptContract()
print(json.dumps({"contract": asdict(contract_1), "health": contract_1.health()}, indent=2))

# %%
from collections import deque

class MemoryStore:
    def __init__(self, k=4):
        self.short = deque(maxlen=k)
        self.summary = ""
        self.episodic = []

    def add_turn(self, role, content):
        self.short.append({"role": role, "content": content})
        if role == "user":
            self.episodic.append(content[:160])

    def pack(self):
        return {"summary": self.summary, "recent": list(self.short), "episodes": self.episodic[-5:]}

mem = MemoryStore()
mem.add_turn("user", "My plan is Pro")
mem.add_turn("assistant", "Noted: plan=Pro")
mem.summary = "User on Pro plan"
print(mem.pack())

# %%
# Semantic memory stub: bag-of-words retrieval
DOCS = ["refund policy under $5", "SSO allowlist redirects", "P0 outage page oncall"]

def retrieve(q: str, k=2):
    qw = set(q.lower().split())
    scored = sorted(DOCS, key=lambda d: len(qw & set(d.split())), reverse=True)
    return scored[:k]

print(retrieve("need refund for small charge"))

# %% [markdown]
# ### Worked scenario — Project 2 — Support Agent with Memory
#
# **Situation:** A team wants to productionize a feature involving **Project 2 — Support Agent with Memory**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Project 3 — Plan-Execute Trip Planner
#
# ### Definition
# **Project 3 — Plan-Execute Trip Planner** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 3 — Plan-Execute Trip Planner as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 3 — Plan-Execute Trip Planner
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agentic systems: runaway tool loops, unverifiable plans, and missing human gates
#
# ### When to use
# Use Project 3 — Plan-Execute Trip Planner when your product path depends on this concern in agentic systems. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 3 — Plan-Execute Trip Planner" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 3 — Plan-Execute Trip Planner"
    notebook: str = "10-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_2 = ConceptContract()
print(json.dumps({"contract": asdict(contract_2), "health": contract_2.health()}, indent=2))

# %%
from enum import Enum

class Phase(Enum):
    PLAN = "plan"
    ACT = "act"
    CHECK = "check"
    DONE = "done"

def agent_loop(goal: str, max_steps=3):
    log = []
    phase = Phase.PLAN
    for step in range(max_steps):
        if phase == Phase.PLAN:
            plan = [f"step{i+1}" for i in range(2)]
            log.append(("plan", plan)); phase = Phase.ACT
        elif phase == Phase.ACT:
            log.append(("act", f"execute {goal}")); phase = Phase.CHECK
        elif phase == Phase.CHECK:
            log.append(("check", "ok")); phase = Phase.DONE
        else:
            break
    return log

print(agent_loop("triage ticket"))

# %%
# Supervisor routes to specialists
def route_intent(text: str) -> str:
    t = text.lower()
    if "refund" in t or "invoice" in t: return "billing_agent"
    if "login" in t or "sso" in t: return "auth_agent"
    return "general_agent"

for q in ["refund please", "SSO loop", "hello"]:
    print(q, "->", route_intent(q))

# %% [markdown]
# ## Project 4 — Multi-Agent Review Duo
#
# ### Definition
# **Project 4 — Multi-Agent Review Duo** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 4 — Multi-Agent Review Duo as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 4 — Multi-Agent Review Duo
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agentic systems: runaway tool loops, unverifiable plans, and missing human gates
#
# ### When to use
# Use Project 4 — Multi-Agent Review Duo when your product path depends on this concern in agentic systems. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 4 — Multi-Agent Review Duo" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 4 — Multi-Agent Review Duo"
    notebook: str = "10-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_3 = ConceptContract()
print(json.dumps({"contract": asdict(contract_3), "health": contract_3.health()}, indent=2))

# %%
from enum import Enum

class Phase(Enum):
    PLAN = "plan"
    ACT = "act"
    CHECK = "check"
    DONE = "done"

def agent_loop(goal: str, max_steps=3):
    log = []
    phase = Phase.PLAN
    for step in range(max_steps):
        if phase == Phase.PLAN:
            plan = [f"step{i+1}" for i in range(2)]
            log.append(("plan", plan)); phase = Phase.ACT
        elif phase == Phase.ACT:
            log.append(("act", f"execute {goal}")); phase = Phase.CHECK
        elif phase == Phase.CHECK:
            log.append(("check", "ok")); phase = Phase.DONE
        else:
            break
    return log

print(agent_loop("triage ticket"))

# %%
# Supervisor routes to specialists
def route_intent(text: str) -> str:
    t = text.lower()
    if "refund" in t or "invoice" in t: return "billing_agent"
    if "login" in t or "sso" in t: return "auth_agent"
    return "general_agent"

for q in ["refund please", "SSO loop", "hello"]:
    print(q, "->", route_intent(q))

# %% [markdown]
# ### Worked scenario — Project 4 — Multi-Agent Review Duo
#
# **Situation:** A team wants to productionize a feature involving **Project 4 — Multi-Agent Review Duo**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Project 5 — HITL Refund Gate
#
# ### Definition
# **Project 5 — HITL Refund Gate** is a capstone-style practice block. You will build something end-to-end that stitches earlier concepts into a small but realistic system.
#
# ### Why it matters
# Projects convert vocabulary into muscle memory and surface integration bugs that section demos hide.
#
# ### How it works
# Time-box an MVP, define acceptance checks, implement, then harden (errors, logging, eval).
#
# ### Intuition
# Ship a thin vertical slice before polishing horizontals.
#
# ### Pitfalls
# - Treating Project 5 — HITL Refund Gate as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Project 5 — HITL Refund Gate
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agentic systems: runaway tool loops, unverifiable plans, and missing human gates
#
# ### When to use
# Use Project 5 — HITL Refund Gate when your product path depends on this concern in agentic systems. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Project 5 — HITL Refund Gate" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Project 5 — HITL Refund Gate"
    notebook: str = "10-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_4 = ConceptContract()
print(json.dumps({"contract": asdict(contract_4), "health": contract_4.health()}, indent=2))

# %%
# Demo: before/after quality rubric for "Project 5 — HITL Refund Gate"
def score_artifact(artifact: dict, rubric: list[str]) -> dict:
    missing = [r for r in rubric if not artifact.get(r)]
    return {"score": round(1 - len(missing)/max(1,len(rubric)), 2), "missing": missing}

rubric = ["definition", "example", "failure_mode", "metric"]
weak = {"definition": "Project 5 — HITL Refund Gate"}
strong = {"definition": "Project 5 — HITL Refund Gate", "example": "worked example", "failure_mode": "empty input", "metric": "exact_match"}
print("weak", score_artifact(weak, rubric))
print("strong", score_artifact(strong, rubric))

# %%
# Demo: operational checklist runner for "Project 5 — HITL Refund Gate"
checks = {
    "has_owner": True,
    "has_eval_set": True,
    "has_token_budget": False,
    "has_alert": False,
}
failed = [k for k, ok in checks.items() if not ok]
print({"topic": "Project 5 — HITL Refund Gate", "passed": len(checks)-len(failed), "failed": failed})

# %% [markdown]
# ## Lightweight Evaluation
#
# ### Definition
# **Lightweight Evaluation** is a core building block in 10-agent-projects within agentic systems. Treat it as an operator with a limited toolbelt and a shift lead (you): something you can name, version, test, and operate.
#
# ### Why it matters
# In agentic systems, weak designs around Lightweight Evaluation typically surface as runaway tool loops, unverifiable plans, and missing human gates. Investing here improves reliability, debuggability, and the ability to change models later.
#
# ### How it works
# For Lightweight Evaluation: (1) write an explicit input/output contract, (2) implement the minimal happy path, (3) validate and add guardrails, (4) cover golden + adversarial fixtures, (5) wire observability. Your durable artifacts should look like loops, memories, tools, and stop conditions.
#
# ### Intuition
# Explain Lightweight Evaluation as an operator with a limited toolbelt and a shift lead (you). If a new engineer cannot tell what is trusted input, what is allowed action, and what 'done' means, the design is still fuzzy.
#
# ### Pitfalls
# - Treating Lightweight Evaluation as a one-time playground experiment instead of a versioned artifact
# - No success criteria or eval set for Lightweight Evaluation
# - Ignoring cost/latency tradeoffs while chasing marginal quality
# - Missing adversarial cases typical of agentic systems: runaway tool loops, unverifiable plans, and missing human gates
#
# ### When to use
# Use Lightweight Evaluation when your product path depends on this concern in agentic systems. Prefer the simplest design that meets quality, latency, and safety budgets—and prove it with fixtures.

# %%
# Demo: make "Lightweight Evaluation" concrete as a checkable contract
from dataclasses import dataclass, field, asdict
import json

@dataclass
class ConceptContract:
    name: str = "Lightweight Evaluation"
    notebook: str = "10-agent-projects"
    must_have: list = field(default_factory=lambda: [
        "clear inputs/outputs",
        "failure behavior defined",
        "eval fixtures exist",
    ])
    risks: list = field(default_factory=lambda: [
        "silent quality drift",
        "unbounded cost/latency",
    ])

    def health(self) -> dict:
        return {
            "concept": self.name,
            "checks": len(self.must_have),
            "risks": len(self.risks),
            "ready_for_design_review": len(self.must_have) >= 3,
        }

contract_5 = ConceptContract()
print(json.dumps({"contract": asdict(contract_5), "health": contract_5.health()}, indent=2))

# %%
GOLDEN = [{"x": "charged twice", "y": "billing"}, {"x": "SSO", "y": "auth"}]

def predict(x: str) -> str:
    return "billing" if "charge" in x.lower() or "invoice" in x.lower() else ("auth" if "sso" in x.lower() or "login" in x.lower() else "other")

def eval_prompt(name: str):
    rows = [(g["x"], g["y"], predict(g["x"])) for g in GOLDEN]
    acc = sum(y == p for _, y, p in rows) / len(rows)
    return {"name": name, "accuracy": acc, "rows": rows}

print(eval_prompt("v1"))

# %%
import hashlib

def prompt_version(text: str) -> str:
    return "pv_" + hashlib.sha1(text.encode()).hexdigest()[:10]

a = "Label tickets carefully"
b = "Label tickets as billing|auth|outage|other. JSON only."
print(prompt_version(a), prompt_version(b))

# %% [markdown]
# ### Worked scenario — Lightweight Evaluation
#
# **Situation:** A team wants to productionize a feature involving **Lightweight Evaluation**.
#
# **Walkthrough:**
# 1. Write a one-sentence success metric.
# 2. Define inputs, outputs, and hard constraints.
# 3. Implement the smallest demo that can fail loudly.
# 4. Add one adversarial fixture (empty, hostile, or oversized input).
# 5. Decide ship/no-ship using the metric—not eloquence.

# %% [markdown]
# ## Comparison Snapshot
#
# Use this table when reviewing designs in **Agent Projects**.
#
# | Topic | Do | Don't |
# |-------|----|-------|
# | Project 1 — Research ReAct Agent | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 2 — Support Agent with Memory | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 3 — Plan-Execute Trip Planner | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 4 — Multi-Agent Review Duo | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Project 5 — HITL Refund Gate | Design carefully; measure; bound cost | Skipping eval / unbounded loops |
# | Lightweight Evaluation | Design carefully; measure; bound cost | Skipping eval / unbounded loops |

# %% [markdown]
# ## Glossary / Key Terms
#
# | Term | Meaning |
# |------|---------|
# | Project 1 — Research ReAct Agent | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 2 — Support Agent with Memory | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 3 — Plan-Execute Trip Planner | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 4 — Multi-Agent Review Duo | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Project 5 — HITL Refund Gate | Key concept covered in this notebook; see its section for definition and pitfalls |
# | Lightweight Evaluation | Key concept covered in this notebook; see its section for definition and pitfalls |

# %% [markdown]
# ## Summary & Key Takeaways
#
# - **Agent Projects** is a production concern: contracts, evals, and guardrails beat vibe-driven prompting.
# - Every major topic above includes definition, motivation, mechanism, intuition, pitfalls, and usage guidance—use that checklist in design reviews.
# - Prefer small, measurable demos before framework sprawl.
# - Bound loops, validate tool args, and keep API keys in environment variables (`YOUR_API_KEY` is a placeholder only).
# - Carry forward: connect these ideas to the next notebooks in **10-agentic-ai-concepts**.

# %% [markdown]
# ## Try It Yourself
#
# 1. Implement a failing test/fixture for **Project 1 — Research ReAct Agent**, then fix your demo until it passes.
# 2. Implement a failing test/fixture for **Project 2 — Support Agent with Memory**, then fix your demo until it passes.
# 3. Implement a failing test/fixture for **Project 3 — Plan-Execute Trip Planner**, then fix your demo until it passes.
# 4. Implement a failing test/fixture for **Project 4 — Multi-Agent Review Duo**, then fix your demo until it passes.
# 5. Implement a failing test/fixture for **Project 5 — HITL Refund Gate**, then fix your demo until it passes.
# 6. Estimate token cost for your prompt/tool trace at 1k and 100k requests/day.
# 7. Write a 5-row comparison of two design alternatives from this notebook; pick one with explicit criteria.
# 8. Red-team your solution with empty input, hostile input, and a tool/API timeout.
